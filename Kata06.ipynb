# %% [markdown]
# ## Ejercicio1: Crear y usar listas de Python

# %% [markdown]
# En primer lugar, crea una variable denominada planets. Agrega los ocho planetas (sin Plutón) a la lista. A continuación, muestra el número de planetas.

# %%
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
print('The planets are ',planets)
# Out:
# The planets are  ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']

# %% [markdown]
# Agrega a Plutón a la lista que creaste. Luego muestra tanto el número de planetas como el último planeta de la lista.

# %%
planets.append('Pluto')
print(planets[8])
# Out:
# Pluto

# %% [markdown]
# ## Ejercicio 2: Trabajando con datos de una lista
#
# Comienza agregando el código para crear una lista con los planetas.

# %%
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']

# %% [markdown]
# Solicita al usuario el nombre de un planeta

# %%
planet=input("Favor de escribir un planeta, en inglés y con Mayúscula la primera letra")

# %% [markdown]
# Encuentra el planeta en la lista

# %%
planet_index=planets.index(planet)
print(planet_index)
# Out:
# 4

# %% [markdown]
# Mostrar planetas más cercanos al sol que el que el usuario ingresó

# %%
print(planets[0:planet_index])
# Out:
# ['Mercury', 'Venus', 'Earth', 'Mars']

# %% [markdown]
# Mostrar planetas más alejados del sol que el que el usuario ingresó

# %%
siguiente_planeta=planet_index+1
print(planets[siguiente_planeta:])
# Out:
# ['Saturn', 'Uranus', 'Neptune']
