# %% [markdown]
# ## Ejercicio 1 Trabajar con argumentos en funciones
#
# Los argumentos requeridos en las funciones se utilizan cuando las funciones necesitan que esos argumentos funcionen correctamente. En este ejercicio, construirás un informe de combustible que requiere información de varias ubicaciones de combustible en todo el cohete.

# %% [markdown]
# Comienza por crear una función que necesite tres lecturas de combustible y devuelva un informe:

# %%
def combustible(comb1,comb2,comb3):
    promedio=((comb1+comb2+comb3)/3)
    print(f'El combustible del tanque 1 es {comb1}\nEl combustible del tanque 2 es {comb2}\nEl combustible del tanque 3 es {comb3}\nEl promedio de combustible es {promedio}')

# %% [markdown]
# Ahora que hemos definido la función de informes, vamos a comprobarlo. Para esta misión, los tanques no están llenos:

# %%
combustible(12,30,54)
# Out:
# El combustible del tanque 1 es 12
# El combustible del tanque 2 es 30
# El combustible del tanque 3 es 54
# El promedio de combustible es 32.0

# %% [markdown]
# En lugar de simplemente crear el informe, la función también está calculando el promedio. Mejora la legibilidad extrayendo el cálculo promedio de la función en una nueva función para que el promedio se pueda hacer de forma independiente:

# %%
def fmean(comb1,comb2,comb3):
  mean = (comb1+comb2+comb3)/3
  return mean


print(fmean(1,2,3))
# Out:
# 2.0

# %% [markdown]
# Ahora actualiza la función de informes para llamar a la nueva función del promedio:

# %%
def combustible(comb1,comb2,comb3):
    p=fmean(comb1,comb2,comb3)
    print(f'El combustible del tanque 1 es {comb1}\nEl combustible del tanque 2 es {comb2}\nEl combustible del tanque 3 es {comb3}\nEl promedio de combustible es {p}')

combustible(30,35,40)
# Out:
# El combustible del tanque 1 es 30
# El combustible del tanque 2 es 35
# El combustible del tanque 3 es 40
# El promedio de combustible es 35.0

# %% [markdown]
# ## Ejercicio 2 Trabajar con argumentos de palabras clave en funciones
#
# En este ejercicio, construirás un informe de cohete que requiere varias piezas de información, como el tiempo hasta el destino, el combustible a la izquierda y el nombre del destino. Comienza por crear una función que creará un informe preciso de la misión:
#
#  Función con un informe preciso de la misión. Considera hora de prelanzamiento, tiempo de vuelo, destino, tanque externo y tanque interno

# %%
def informe(hora,tiempo,destino,tanque1,tanque2):
      print(f'El destino es: {destino}\nLa hora de prelanzamiento es {hora}pm\n El tiempo de vuelo es: {tiempo} minutos\nEl tanque externo tiene {tanque1}% y el tanque interno tiene {tanque2}')

informe(12,44,"Marte",25,40)
# Out:
# El destino es: Marte
# La hora de prelanzamiento es 12pm
#  El tiempo de vuelo es: 44 minutos
# El tanque externo tiene 25% y el tanque interno tiene 40

# %% [markdown]
# La función es problemática porque no se puede adaptar para minutos adicionales o tanques adicionales de combustible. Hazlo más flexible permitiendo cualquier número de pasos basados en el tiempo y cualquier número de tanques. En lugar de usar *args y **kwargs, aprovecha el hecho de que puedes usar cualquier nombre que desees. Asegurate que la función sea más legible mediante el uso de nombres de variables que están asociados con las entradas, como *minutes y **fuel_reservoirs:

# %%
def informe(destino2, *minutos2, **tanques2):
       print( f"""El destino es: {destino2}\nEl tiempo de vuelo es: {sum(minutos2)} minutos\nCapacidad de los tanques: {sum(tanques2.values())}""")

informe("Marte", 24, 13, 5, Tanque1=25, Tanque2=30, Tanque3=20)
# Out:
# El destino es: Marte
# El tiempo de vuelo es: 42 minutos
# Capacidad de los tanques: 75

# %% [markdown]
# Debido a que el combustible que queda en los tanques es específico de cada tanque, actualiza la función para usar el nombre de cada tanque en el informe:

# %%
def informe(destino2, *minutos2, **tanques2):
       print( f"""El destino es: {destino2}\nEl tiempo de vuelo es: {sum(minutos2)} minutos\nCapacidad de los tanques: {sum(tanques2.values())} de los cuales:""")
       for i, tanquee in tanques2.items():
        print(f'{i}: {tanquee}')

informe("Marte", 24, 13, 5, Tanque1=25, Tanque2=30, Tanque3=20)
# Out:
# El destino es: Marte
# El tiempo de vuelo es: 42 minutos
# Capacidad de los tanques: 75 de los cuales:
# Tanque1: 25
# Tanque2: 30
# Tanque3: 20
